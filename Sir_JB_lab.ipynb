# %%
import pandas as pd 
import numpy as np
df = pd.read_excel("D:\Sir Ehtsham\Sir JB Work\Pakistan Ecommerce Dataset11.xlsx")
df.head()
# Out:
#    Unnamed: 0   item_id          status  created_at  \
# 0           0       NaN             NaN         NaN
# 1           1  211131.0        complete    07-01-16
# 2           2  262253.0  order_refunded  10/13/2016
# 3           3  216143.0        complete   7/19/2016
# 4           4  231453.0        complete   8/17/2016
#
#                                sku    price  qty_ordered  grand_total  \
# 0                              NaN      NaN          NaN          NaN
# 1                kreations_YI 06-L   1950.0          1.0       1950.0
# 2  samsungGALAXY J510F-2016 DS LTE  27000.0          1.0      27000.0
# 3                    RS_Nan Khatai    210.0          1.0        210.0
# 4    Al Muhafiz Sohan Halwa Almond    460.0          1.0        460.0
#
#    increment_id  category_name_1  ... payment_method  Working Date BI Status  \
# 0           NaN              NaN  ...            NaN           NaN       NaN
# ...

# %%
data1 = df.fillna({"item_id":"Nil","status":"No Status","created_at":"inf"})
display(pd.DataFrame(data1))
# Out:
#        Unnamed: 0   item_id          status      created_at  \
# 0               0       Nil       No Status             inf
# 1               1  211131.0        complete        07-01-16
# 2               2  262253.0  order_refunded      10/13/2016
# 3               3  216143.0        complete       7/19/2016
# 4               4  231453.0        complete       8/17/2016
# ...           ...       ...             ...             ...
# 65539       65539       Nil            8269  order_refunded
# 65540       65540       Nil            1631          refund
# 65541       65541       Nil           17057        Canceled
# 65542       65542       Nil             356        Received
# 65543       65543       Nil           65352           Total
#
#                                    sku    price  qty_ordered  grand_total  \
# 0                                  NaN      NaN          NaN          NaN
# 1                    kreations_YI 06-L   1950.0          1.0       1950.0
# ...

# %%
data1 = df.fillna(value = 0)
display(pd.DataFrame(data1))
# Out:
#        Unnamed: 0   item_id          status      created_at  \
# 0               0       0.0               0               0
# 1               1  211131.0        complete        07-01-16
# 2               2  262253.0  order_refunded      10/13/2016
# 3               3  216143.0        complete       7/19/2016
# 4               4  231453.0        complete       8/17/2016
# ...           ...       ...             ...             ...
# 65539       65539       0.0            8269  order_refunded
# 65540       65540       0.0            1631          refund
# 65541       65541       0.0           17057        Canceled
# 65542       65542       0.0             356        Received
# 65543       65543       0.0           65352           Total
#
#                                    sku    price  qty_ordered  grand_total  \
# 0                                    0      0.0          0.0          0.0
# 1                    kreations_YI 06-L   1950.0          1.0       1950.0
# ...

# %%
data1 = df.fillna(df.mean())
data2 = data1.fillna(value = 0)
data3 = data2.replace({"sku":0},"Gone")#Values changes in specific column
#data2 = data1.isna().sum().sum()
#print(data2)
#data3 = data1.isna().any()
#print(data3)
#data4 = data1["grand_total"].isna().sum()
#print(data4)
# = data1.replace(df.mean())
display(pd.DataFrame(data3))
#data5.head()
# Out:
# C:\Users\Laptop\AppData\Local\Temp\ipykernel_2584\887259537.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data1 = df.fillna(df.mean())
#        Unnamed: 0       item_id          status      created_at  \
# 0               0  251145.53353               0               0
# 1               1  211131.00000        complete        07-01-16
# 2               2  262253.00000  order_refunded      10/13/2016
# 3               3  216143.00000        complete       7/19/2016
# 4               4  231453.00000        complete       8/17/2016
# ...           ...           ...             ...             ...
# 65539       65539  251145.53353            8269  order_refunded
# 65540       65540  251145.53353            1631          refund
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_excel("D:\Sir Ehtsham\Sir JB Work\Pakistan Ecommerce Dataset11.xlsx")
data1 = df.fillna(value = 0)
data1.describe()
column_name = "grand_total"
data = pd.DataFrame(data1).plot(kind = "box",title = "boxplot",column = [column_name])
plt.show()

# %%
df = pd.read_excel("D:\Sir Ehtsham\Sir JB Work\Pakistan Ecommerce Dataset11.xlsx")
dups = df.duplicated(subset = ["sku"])
print("Number of dublicate rows  = %d "% (dups.sum()))
data_2 = dups.loc[[101,12]]
print("Number of rows before discarding dublicate = %d"%(dups.shape[0]))
data_3 = df.drop_duplicates(subset = ["sku"])
print("Number of rows after discarding dublicate = %d"%(data_3.shape[0]))
display(pd.DataFrame(data_2))
# Out:
# Number of dublicate rows  = 64700
# Number of rows before discarding dublicate = 65544
# Number of rows after discarding dublicate = 844
#          0
# 101   True
# 39   False

# %%
df["price"] = pd.to_numeric(df["price"])

# %%
z = (df - df.mean())/df.std()
z[20:25]
print("Number of rows before discarding outliers = %d"%(z.shape[0]))
z2 = z.loc[((z>-3).sum(axis = 1)==9)&((z<=3).sum(axis = 1)==9),:]
print("Number of rows after discarding outliers = %d"%(z2.shape[0]))
z2.boxplot(figsize = (20,3))
df.boxplot(figsize = (20,3))
# Out:
# C:\Users\Laptop\AppData\Local\Temp\ipykernel_7548\3865517477.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z = (df - df.mean())/df.std()
# C:\Users\Laptop\AppData\Local\Temp\ipykernel_7548\3865517477.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z = (df - df.mean())/df.std()
# Number of rows before discarding outliers = 65544
# Number of rows after discarding outliers = 1311
# <Axes: >

# %%
z2.boxplot(figsize = (20,3))
# Out:
# <Axes: >
